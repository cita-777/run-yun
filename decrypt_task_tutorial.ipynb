# %%
# 必要的包
import base64
import gzip
from main import decrypt_sm4, PUBLIC_KEY, PRIVATE_KEY
# from main import decrypt_sm2 # 代码提供的decrypt_sm2过不了验签，先不用，网上随便搜一个sm在线加密解密，选c1c3c2模式

# %%
# 你可以运行这里copy公钥和私钥(统一的)
print("公钥：" + base64.b64encode(PUBLIC_KEY).decode("utf-8"))
print("私钥：" + base64.b64encode(PRIVATE_KEY).decode("utf-8"))
# Out:
# 公钥：BL7JvEAV7Wci0h5YAysN0BPNVdcUhuyJszJLRwnurav0CGftcrVcvrWeCPBIjIIBF371teRbrCS9V1Wyq7i3Arc=
# 私钥：P3s0+rMuY4Nt5cUWuOCjMhDzVNdom+W0RvdV6ngM+/E=

# %%
cipherkey_plaintext = base64.b64decode("8wh28+yKlviztxbHpwuRvA==") # 你的解密后的密钥

# %%
# 运行这个，查看解密后的内容
text = gzip.decompress(decrypt_sm4("(your string)asdf==", cipherkey_plaintext)).decode()
print(text)
# 注意gzip，还有python3是严格区分bytes和string类型的，不能混用，记得decode和encode
# Out:
# {"msg":"操作成功","code":200,"data":{"id":2868916,"studentId":"2023217340","raType":"T3","recordStartTime":"2023-09-23 20:30:24","recordMileage":3.99,"recodePace":6.23,"recodeCadence":151,"recodeDislikes":4,"isQualified":"1","appealStatus":"R5","duration":1490,"pointsList":[{"id":0,"point":"118.71626181763853,30.905802517362268","speed":4.41,"runStatus":1,"runRecordId":0,"runTime":"10","isFence":"Y","runStep":"13","runMileage":"11.515722274780273"},{"id":0,"point":"118.71629866374207,30.905692397835757","speed":3.77,"runStatus":1,"runRecordId":0,"runTime":"12","isFence":"Y","runStep":"13","runMileage":"24.255083084106445"},{"id":0,"point":"118.71631983074029,30.905646584440387","speed":4.32,"runStatus":1,"runRecordId":0,"runTime":"14","isFence":"Y","runStep":"23","runMileage":"29.7349853515625"},{"id":0,"point":"118.71634626290829,30.90559790659911","speed":4.37,"runStatus":1,"runRecordId":0,"runTime":"16","isFence":"Y","runStep":"23","runMileage":"35.70634841918945"},{"id":0,"point":"118.7163919082051,30.905529441220764","speed":4.37,"runStatus":1,"runRecordId":0,"runTime":"18","isFence":"Y","runStep":"33","runMileage":"44.47691345214844"},{"id":0,"point":"118.71645934396767,30.905473084454353","speed":4.26,"runStatus":1,"runRecordId":0,"runTime":"20","isFence":"Y","runStep":"33","runMileage":"53.458251953125"},{"id":0,"point":"118.71651747374383,30.905444559013144","speed":3.96,"runStatus":1,"runRecordId":0,"runTime":"22","isFence":"Y","runStep":"43","runMileage":"59.84721374511719"},{"id":0,"point":"118.71659326233303,30.905422799440046","speed":4.39,"runStatus":1,"runRecordId":0,"runTime":"24","isFence":"Y","runStep":"43","runMileage":"67.47205352783203"},{"id":0,"point":"118.7166649842413,30.90541255177499","speed":4.71,"runStatus":1,"runRecordId":0,"runTime":"26","isFence":"Y","runStep":"53","runMileage":"74.4090576171875"},{"id":0,"point":"118.71673975046896,30.905412584917148","speed":4.0,"runStatus":1,"runRecordId":0,"runTime":"28","isFence":"Y","runStep":"53","runMileage":"81.54228210449219"},{"id":0,"point":"118.71681618182261,30.905434274532105","speed":4.48,"runStatus":1,"runRecordId":0,"runTime":"30","isFence":"Y","runStep":"63","runMileage":"89.22286224365234"},{"id":0,"point":"118.71689706863005,30.905468684332313","speed":4.44,"runStatus":1,"runRecordId":0,"runTime":"32","isFence":"Y","runStep":"73","runMileage":"97.83648681640625"},{"id":0,"point":"118.71695701857688,30.905507756794275","speed":4.86,"runStatus":1,"runRecordId":0,"runTime":"34","isFence":"Y","runStep":"73","runMileage":"105.01913452148438"},{"id":0,"point":"118.71702771839627,30.905566550057358","speed":3.91,"runStatus":1,"runRecordId":0,"runTime":"36","isFence":"Y","runStep":"83","runMileage":"114.4126205444336"},{"id":0,"point":"118.71707092634998,30.905632136068515","speed":4.25,"runStatus":1,"runRecordId":0,"runTime":"38","isFence":"Y","runStep":"83","runMileage":"122.7899169921875"},{"id":0,"point":"118.71709453121446,30.905697756282986","speed":4.48,"runStatus":1,"runRecordId":0,"runTime":"40","isFence":"Y","runStep":"93","runMileage":"130.4261932373047"},{"id":0,"point":"118.71708609555778,30.905776838044577","speed":4.58,"runStatus":1,"runRecordId":0,"runTime":"42","isFence":"Y","runStep":"93","runMileage":"139.25643920898438"},{"id":0,"point":"118.71708453336637,30.905848142518753","speed":4.71,"runStatus":1,"runRecordId":0,"runTime":"44","isFence":"Y","runStep":"103","runMileage":"147.18653869628906"},{"id":0,"point":"118.71707740352248,30.90591730132203","speed":4.58,"runStatus":1,"runRecordId":0,"runTime":"46","isFence":"Y","runStep":"113","runMileage":"154.90667724609375"},{"id":0,"point":"118.71707151226329,30.90597643123903","speed":4.76,"runStatus":1,"runRecordId":0,"runTime":"48","isFence":"Y","runStep":"113","runMileage":"161.50559997558594"},{"id":0,"point":"118.71706752367767,30.90603844521523","speed":4.86,"runStatus":1,"runRecordId":0,"runTime":"50","isFence":"Y","runStep":"123","runMileage":"168.41172790527344"},{"id":0,"poi ...

# %%
# 保存到tasklist_{last+1}.json
import os
path = "./tasks"
files = os.listdir(path)
last = 0
target = None
if len(files) == 0:
    target = os.path.join(path, "tasklist_0.json")
else:
    for file in files:
        if f'tasklist_{last}.json' in file:
            last += 1
        else:
            target = os.path.join(path, f"tasklist_{last}.json")
            break
    if target == None:
        target = os.path.join(path, f"tasklist_{last}.json")
with open(file=target,mode='w+', encoding="utf-8") as f:
    print(f"write to {target}")
    f.write(text)
    f.flush()
# Out:
# write to ./tasks\tasklist_0.json
